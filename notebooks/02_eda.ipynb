# %% [markdown]
# # 02 — Exploratory Data Analysis
#
# All figures are saved to `reports/figures/`.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/cleaned.csv')
print(f"Loaded cleaned data: {df.shape}")

# %% [markdown]
# ## 1. Univariate — Numeric Features (Histograms + KDE)

# %%
from src.eda import plot_univariate_numeric
plot_univariate_numeric(df)
print('Saved: univariate_numeric.png')

# %% [markdown]
# ## 2. Univariate — Categorical Features (Countplots)

# %%
from src.eda import plot_univariate_categorical
plot_univariate_categorical(df)
print('Saved: univariate_categorical.png')

# %% [markdown]
# ## 3. Bivariate — Numeric vs Depression (Boxplots)

# %%
from src.eda import plot_bivariate_numeric
plot_bivariate_numeric(df)
print('Saved: bivariate_numeric_boxplots.png')

# %% [markdown]
# ## 4. Bivariate — Categorical vs Depression (Countplots)

# %%
from src.eda import plot_bivariate_categorical
plot_bivariate_categorical(df)
print('Saved: bivariate_categorical_countplots.png')

# %% [markdown]
# ## 5. Mean Numeric Features by Depression Class

# %%
from src.eda import plot_mean_by_depression
plot_mean_by_depression(df)
print('Saved: mean_features_by_depression.png')

# %% [markdown]
# ## 6. Correlation Heatmap

# %%
from src.eda import plot_correlation_heatmap
corr = plot_correlation_heatmap(df)
print('Top correlations with Depression:')
print(corr['Depression'].abs().sort_values(ascending=False).head(10))

# %% [markdown]
# ## 7. Point-Biserial Correlation with Target

# %%
from src.eda import compute_point_biserial
pb_corr = compute_point_biserial(df)
print('Top 5 features by |point-biserial r|:')
print(pb_corr.head(5))

# %% [markdown]
# ## 8. Class Distribution Pie Chart

# %%
from src.eda import plot_class_distribution
plot_class_distribution(df)
print('Saved: class_distribution_pie.png')

# %% [markdown]
# ## 9. Pair Plot — Top 5 Correlated Features

# %%
from src.eda import plot_pairplot
top5 = pb_corr.head(5).index.tolist()
# filter to columns that exist in df (pre-encoding names)
top5_raw = [f for f in top5 if f in df.columns][:5]
plot_pairplot(df, top5_raw)
print('Saved: pairplot_top5.png')
print(f"Top 5 predictive features: {top5_raw}")
